# %%
import pandas as pd

# %%
df = pd.read_csv("mabel.txt",header=None,on_bad_lines='skip',encoding='utf8')

# %%
df
# Out:
#            0                                                  1
# 0   05/12/19   1:42 pm - Messages to this chat and calls are...
# 1   05/12/19   1:42 pm - Mabel Infoziant: Hi this is Mabel w...
# 2   05/12/19   1:42 pm - Mabel Infoziant: What’s your full name
# 3   05/12/19                      1:42 pm - AR❤: Ramisha Rani K
# 4   05/12/19                      1:42 pm - Mabel Infoziant: Ok
# 5   05/12/19   1:42 pm - Mabel Infoziant: ramisharanik@gmail...
# 6   05/12/19          1:43 pm - Mabel Infoziant: Your email Id?
# 7   05/12/19                             1:43 pm - AR❤: Yes Mam
# 8   05/12/19   1:43 pm - Mabel Infoziant: I will send 2 abst...
# 9   05/12/19                            1:43 pm - AR❤: Yeah mam
# 10  05/12/19   1:43 pm - Mabel Infoziant: Give me the list t...
# 11  05/12/19   1:43 pm - Mabel Infoziant: Send me cbe office...
# 12  05/12/19   1:44 pm - AR❤: Yeah Mam within Evening I will...
# 13  05/12/19   1:45 pm - AR❤: Tomorrow I have to visit the o...
# ...

# %%
df =df.drop(0)
df.columns = ["Date","Chat"]
Message = df["Chat"].str.split("-",n=1,expand = True)
df["Time"]= Message[0]
Message1 = Message[1].str.split(":",n=1,expand = True)
df["Name"]= Message1[0]
df["Chat"]= Message1[1]
df = df[["Date","Time","Name","Chat"]]
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 1 to 50
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50 non-null     str
#  1   Time    50 non-null     str
#  2   Name    50 non-null     str
#  3   Chat    50 non-null     str
# dtypes: str(4)
# memory usage: 5.1 KB

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dataset = df
dataset.dropna(inplace= True)

# %%
sid = SentimentIntensityAnalyzer()
senti = sid.polarity_scores(dataset['Chat'][4])
senti
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}

# %%
def sentimentalAnalysis(data,columnname):
    data.dropna(inplace= True)
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    sid = SentimentIntensityAnalyzer()
    data['scores'] = data[columnname].apply(lambda text: sid.polarity_scores(text))
    data['compound'] = data['scores'].apply(lambda score_dict: score_dict['compound'])
    data['neg']= data['scores'].apply(lambda score_dict: score_dict['neg'])
    data['neu']= data['scores'].apply(lambda score_dict: score_dict['neu'])
    data['pos']= data['scores'].apply(lambda score_dict: score_dict['pos'])
    data['comp_score'] = data['compound'].apply(lambda c:'pos' if c>=0 else 'neg')
    posneg= pd.DataFrame(data['comp_score'].value_counts())
    return data, posneg

# %%
data_senti, pos = sentimentalAnalysis(dataset,columnname='Chat')

# %%
data_senti
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
pos
# Out:
#             count
# comp_score
# pos            48
# neg             2

# %%
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english')
dtm = tfidf.fit_transform(df["Chat"])
dtm
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 188 stored elements and shape (50, 122)>

# %%
from sklearn.decomposition import NMF
nmf_model = NMF(n_components = 5,random_state = 42)
nmf_model.fit(dtm)
# Out:
# NMF(n_components=5, random_state=42)

# %%
for index,topic in enumerate (nmf_model.components_):
    results = ([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print(results)
# Out:
# ['okay', 'shall', 'updates', 'free', 'kk', 'abstract', 'read', 'sure', 'yeah', 'mam']
# ['working', 'ya', 'waiting', 'send', 'just', 'know', 'tomorrow', 'mam', 'thank', 'ok']
# ['start', 'details', 'abstracts', 'students', 'phone', 'ask', 'office', 'vignesh', 'number', 'send']
# ['night', 'plan', 'late', 'spoke', 'mabel', 'just', 'couldn', 'tomorrow', 'church', 'hi']
# ['talk', 'today', '10', 'rani', 'ya', '7pm', 'details', 'ramisha', 'need', 'yes']

# %%
topic_results = nmf_model.transform(dtm)
df["Topic"] = topic_results.argmax(axis = 1)

# %%
df
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
#Creation of Flirt model should be checked with WhatsApp chat each row
flirt_words=['kiss','hug','date', 'cute','beautiful', 'sexy', 'hot','adorable','uma', 'darling','fuck','porn', 'x', 'sex', 'matter', 'nipple', 'virgin', 'sperm','seduce', 'condom','kk']
flirt_set = set(flirt_words)
def check_for_flirtword(data,columnname):
    df['flirt_message'] = df[columnname].apply(lambda x: 'Yes' if set(str(x).lower().split()) & flirt_set else 'No')                
    flirt= pd.DataFrame(data['flirt_message'])   
    return data,flirt

# %%
data,flirt = check_for_flirtword (dataset,"Chat")
data
# Out:
#         Date        Time              Name  \
# 1   05/12/19    1:42 pm    Mabel Infoziant
# 2   05/12/19    1:42 pm    Mabel Infoziant
# 3   05/12/19    1:42 pm                AR❤
# 4   05/12/19    1:42 pm    Mabel Infoziant
# 5   05/12/19    1:42 pm    Mabel Infoziant
# 6   05/12/19    1:43 pm    Mabel Infoziant
# 7   05/12/19    1:43 pm                AR❤
# 8   05/12/19    1:43 pm    Mabel Infoziant
# 9   05/12/19    1:43 pm                AR❤
# 10  05/12/19    1:43 pm    Mabel Infoziant
# 11  05/12/19    1:43 pm    Mabel Infoziant
# 12  05/12/19    1:44 pm                AR❤
# 13  05/12/19    1:45 pm                AR❤
# 14  05/12/19    1:48 pm    Mabel Infoziant
# 15  05/12/19    1:48 pm    Mabel Infoziant
# 16  05/12/19    1:49 pm                AR❤
# 17  05/12/19    2:00 pm                AR❤
# 18  05/12/19    2:04 pm    Mabel Infoziant
# 19  05/12/19    2:04 pm    Mabel Infoziant
# 20  05/12/19    2:06 pm                AR❤
# 21  05/12/19    2:07 pm                AR❤
# ...

# %%
#Talkative, Less Talkative
Talkative=(dataset['Name'].value_counts().idxmax()).upper()
print("More Talktative:", Talkative)
Less_Talktative=(dataset['Name'].value_counts().idxmin()).upper()
print("Less Talktative:", Less_Talktative)
# Out:
# More Talktative:  AR❤
# Less Talktative:  MABEL INFOZIANT

# %%
#Most Active Day, Most Active Time
most_active_date= dataset["Date"].value_counts().idxmax()
print("Most active date:",most_active_date)
# Out:
# Most active date: 05/12/19

# %%
most_active_time= dataset["Time"].value_counts().idxmax()
print("Most Active Time:",most_active_time)
# Out:
# Most Active Time:  1:43 pm

# %%
# Media count sent by each person
media =dataset[dataset["Chat"] == " <media omitted>"]
if len(media):
    media_count = pd.DataFrame(media["Name"].value_counts())
    media_share_freak = media["Name"].value_counts().idxmax()
else:
    media_count = "0"
    media_share_freak = "No Media were shared"
print("media_count shared:",media_count)
print("Who shared maximum media:",media_share_freak)
# Out:
# media_count shared: 0
# Who shared maximum media: No Media were shared

# %%
#Missed calls
missed_voice_call =dataset[dataset["Chat"] == "missed voice call"]
if len(missed_voice_call):
    missedcall_count = pd.DataFrame(missed_voice_call["Name"].value_counts())
    Maximum_missed_call = missed_voice_call["Name"].value_counts().idxmax()
else:
    missedcall_count = "0"
    Maximum_missed_call = "No missed voice call"
print("Total missed voice call:",missedcall_count)
print("From whome maximum missed voice call:",Maximum_missed_call)
# Out:
# Total missed voice call: 0
# From whome maximum missed voice call: No missed voice call

# %%
missed_video_call =dataset[dataset["Chat"] == "missed video call"]
if len(missed_video_call):
    missedcall_count = pd.DataFrame(missed_video_call["Name"].value_counts())
    Maximum_missed_call = missed_video_call["Name"].value_counts().idxmax()
else:
    missedcall_count = "0"
    Maximum_missed_call = "No missed video call"
print("Total missed video call:",missedcall_count)
print("From whome maximum missed video call:",Maximum_missed_call)
# Out:
# Total missed video call: 0
# From whome maximum missed video call: No missed video call
